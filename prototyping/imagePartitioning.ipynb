# %% [markdown]
# # Image partitioning logic
#
#
# ref: https://scikit-image.org/docs/stable/user_guide/numpy_images.html

# %%
import numpy as np
import scipy as sp
import skimage as ski

import matplotlib.pyplot as pp

# %%
image_path = '../imageDBtmp/airport.png'
image = ski.io.imread(image_path)
image_np = np.array(image)

# %%
image_np
# Out:
# array([[[161, 163, 141, 255],
#         [162, 163, 141, 255],
#         [163, 164, 142, 255],
#         ...,
#         [205, 207, 192, 255],
#         [205, 206, 191, 255],
#         [204, 206, 191, 255]],
#
#        [[162, 163, 142, 255],
#         [163, 164, 142, 255],
#         [163, 164, 143, 255],
#         ...,
#         [205, 207, 192, 255],
#         [205, 207, 192, 255],
#         [205, 207, 192, 255]],
#
#        [[163, 164, 143, 255],
#         [164, 165, 143, 255],
#         [164, 165, 144, 255],
#         ...,
#         [206, 208, 193, 255],
#         [206, 208, 193, 255],
#         [205, 207, 192, 255]],
#
#        ...,
#
#        [[190, 186, 168, 255],
#         [191, 188, 171, 255],
#         [192, 189, 172, 255],
#         ...,
#         [189, 189, 169, 255],
#         [197, 197, 177, 255],
#         [197, 197, 178, 255]],
#
#        [[186, 182, 163, 255],
#         [188, 184, 166, 255],
#         [189, 186, 167, 255],
#         ...,
#         [194, 195, 174, 255],
#         [200, 200, 180, 255],
#         [200, 199, 180, 255]],
#
#        [[184, 179, 159, 255],
#         [186, 182, 162, 255],
#         [187, 185, 164, 255],
#         ...,
#         [196, 197, 175, 255],
#         [200, 200, 179, 255],
#         [199, 198, 179, 255]]], dtype=uint8)

# %%
pp.imshow(image_np)
